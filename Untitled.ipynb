# %%
# Define the path to load the model based on whether you're using LoRA or not
model_path = "output/full_model.pth"

device = "cuda" if torch.cuda.is_available() else "cpu"
model = timm.create_model('vit_tiny_patch16_224', pretrained=False, num_classes=10).to("cpu")



# Loading the model weights
model, _ = load_checkpoint(model_path, model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [11], line 10
#       5 model = timm.create_model('vit_tiny_patch16_224', pretrained=False, num_classes=10).to("cpu")
#       9 # Loading the model weights
# ---> 10 model, _ = load_checkpoint(model_path, model)
#
# Cell In [2], line 17, in load_checkpoint(checkpoint_path, model, optimizer)
#      14 checkpoint = torch.load(checkpoint_path)
#      16 # Load model weights
# ---> 17 model.load_state_dict(checkpoint)
#      19 # Load optimizer weights (if provided)
#      20 if optimizer:
#
# File /projects/ec232/venvs/in5310/lib/python3.10/site-packages/torch/nn/modules/module.py:2041, in Module.load_state_dict(self, state_dict, strict)
#    2036         error_msgs.insert(
#    2037             0, 'Missing key(s) in state_dict: {}. '.format(
#    2038                 ', '.join('"{}"'.format(k) for k in missing_keys)))
# ...

# %%
model
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 load_my_models()
#
# Cell In [2], line 39, in load_my_models()
#      30 """
#      31 Loads the fine-tuned models (full or LoRA) with default paths.
#      32
#    (...)
#      35 - lora_model (nn.Module): The loaded LoRA model.
#      36 """
#      37 full_model = timm.create_model('vit_tiny_patch16_224', pretrained=True, num_classes=10)
# ---> 39 full_model =  load_checkpoint("output/full_model.pth", full_model)
#      40 full_model.load_state_dict(checkpoint['model_state_dict'])
#      41 #lora_model_path = '/output/lora_model.pth'
#
# Cell In [2], line 17, in load_checkpoint(checkpoint_path, model, optimizer)
#      14 checkpoint = torch.load(checkpoint_path)
#      16 # Load model weights
# ---> 17 model.load_state_dict(checkpoint)
#      19 # Load optimizer weights (if provided)
# ...
